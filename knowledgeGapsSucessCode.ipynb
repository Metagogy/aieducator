# %%
pythonc1q2 = [('i1':'f1')]
pythonc1q3 = [('i1','s1')]
pythonc1q6 = [('i1','s1'),('s1','s2'),('s1','s3')]
pythonc1q8 = [('i1', 'i3'), ('i3', 'i4'), ('i3', 'f2'), ('i3', 'n1'), ('n1', 'a3')]
pythonc1q4 = [('i2', 'a1')]
pythonc1q5 = [('i1', 's2')]
pythonc1q7 = [('i1', 'c1'), ('c1', 'a2'), ('a2', 'p2'), ('a2', 's4')]
pythonc1q9 = [('t1', 'v1'), ('v1', 'v2')]
pythonc1q10 = [('i1', 'i3'), ('i3', 'a2'), ('a2', 'p2'), ('p2', 'c2')]

# %%
pythonc2q1 = [('i1', 'i3'), ('i3', 'v3')]
pythonc2q2 = [('i1', 'v3'), ('v3', 'o1')]
pythonc2q3 = [('i1', 'i3'), ('i3', 'v3'), ('v3', 'b1'), ('v3', 'h1'), ('v3', 'o2')]
pythonc2q4 = [('i1', 'l1'), ('l1', 'n2')]
pythonc2q5 = [('i1', 't2')]
pythonc2q6 = [('i1', 'n3')]
pythonc2q7 = [('i1', 'l1'), ('l1', 'i6'), ('i6', 'f3'), ('i6', 'f4')]
pythonc2q8 = [('i1', 'i3'), ('i3', 'v3'), ('v3', 'f5')]
pythonc2q9 = [('i1', 'i6'), ('i6', 's7'), ('i6', 's6'), ('s7', 's5')]
pythonc2q10 = [('i1', 'i8'), ('i8', 'e1'), ('e1', 'i6')]
pythonc2q11 = [('i5', 't3'), ('t3', 't5')]
pythonc2q12 = [('i5', 't6'), ('t6', 's8')]
pythonc2q13 = [('i5', 't3'), ('i5', 't6')]
pythonc2q14 = [('c3', 'i1'), ('i1', 'i3'), ('i1', 'f6'), ('f6', 'r1'), ('f6', 'l2'), ('f6', 'd1')]
pythonc2q15 = [('c3', 'i1'), ('i1', 'i3'), ('i1', 'f6'), ('f6', 'r1'), ('f6', 'l2'), ('f6', 'd1'), ('f6', 'd2')]
pythonc2q16 = [('i9', 'i1'), ('i1', 'i3'), ('i1', 'a4'), ('a4', 'f1')]
pythonc2q17 = [('l2', 't7'), ('t7', 'p3'), ('p3', 'a2')]
pythonc2q18 = [('l2', 't7'), ('t7', 'p3'), ('p3', 'o3'), ('o3', 'a2'), ('o3', 'l3'), ('o3', 'c4')]
pythonc2q19 = [('i5', 'f6'), ('f6', 'r1'), ('f6', 'f5'), ('f5', 'i10')]
pythonc2q20 = [('l4', 'f7')]

# %%
pythonc3q1 = [('c5', 'w1'), ('w1', 'i7'), ('w1', 'i6'), ('i6', 'l5'), ('i6', 'b2'), ('l5', 's6'), ('c5', 'f6'), ('f6','l6'), ('f6', 'p1')]
pythonc3q2 = [('i1', 'c5'), ('c5', 'f6'), ('f6', 'r1'), ('f6', 'i7'), ('i7', 'o3'), ('o3', 'a2'), ('o3', 'c4'), ('i7', 'l5'), ('l5', 't8'), ('i1', 'j1')]
pythonc3q3 = [('i1', 'c5'), ('c5', 'f6'), ('f6', 'r1'), ('f6', 'i7'),('i7', 'o3'), ('o3', 'a2'), ('o3', 'c4'), ('i7', 'l5'), ('i1', 'j1')]
pythonc3q4 = [('i1', 'v4'), ('v4', 'f6'), ('f6', 's9'), ('f6', 'i7'), ('i7', 'c4'), ('c4', 'c6'), ('i1', 'f5')]
pythonc3q5 = [('i1', 'i13'), ('i13', 'i14'), ('i13', 'i15'), ('i1', 'f6'), ('f6', 'r1'), ('f6', 's2'), ('f6', 'i16')]
pythonc3q6 = [('i1', 'i17'), ('i17', 'f6'), ('f6', 'r1'), ('f6', 'i18'), ('i1', 'p3')]
pythonc3q7 = [('i1','i3'), ('i1','f6'), ('f6', 'r1'), ('f6','i7'),('i7','o3'),('o3','a2'),('o3','c4'),('i7','p1')]
pythonc3q8 = [('i5','c7'),('c7','f6'),('f6','r1'),('r1','i7')]
pythonc3q9 = [('i1','c5'),('c5','f6'),('f6','r1'),('f6','c5'),('f6','f6'),('f6','l5'),('f6','l5'),('f6','r1')]
pythonc3q10 = [('i1','f6'),('f6','r2'),('f6','i7'),('i7','o3'),('o3','a2'),('o3','c4'),('i7','e2'),('e2','e2')]
pythonc3q11 = [('i1','f6'),('f6','r1'),('f6','i7'),('i7','a2'),('i7','c4')]
pythonc3q12 = [('i1','f6'),('f6','r1'),('f6','i7'),('i7','a2'),('i7','c4')]
pythonc3q13 = [('c5','i1'),('c5','j2'),('i1','f6'),('f6','r1'),('f6','i7'),('f6','f6'),('f6','s9'),('f6','i7')]
pythonc3q14 = [('a5','w1'),('w1','l2'),('l2','m1')]
pythonc3q15 = [('i1','i7'),('i7','a2'),('i7','c4'),('i7','e3')]
pythonc3q16 = [('i5','s10'),('s10','i11')]
pythonc3q17 = [('i1','i3'),('i1','a5'),('a5','c8'),('c8','w1'),('w1','i6')]
pythonc3q18 = [('i1','f6'),('f6','r1')]
pythonc3q19 = [('i1','f6'),('f6','s9'),('f6','i7')]
pythonc3q20 = [('i1','i3'),('i1','i6'),('i6','c4'),('i6','f6'),('f6','r1'),('f6','i6')]

# %%
pythonc4q1 = [('c9', 't8'), ('c9', 'i1')]
pythonc4q2 = [('c9', 't7'), ('c9', 'i1')]
pythonc4q3 = [('c9', 'f8'), ('c9', 'i1'), ('i1', 'p1')]
pythonc4q4 = [('c9', 's2')]
pythonc4q5 = [('c9','i7'), ('i7', 'r2')]
pythonc4q7 = [('l8', 'm2'), ('m2', 'l7')]
pythonc4q8 = [('c9', 'l2')]
pythonc4q9 = [('c9', 'i11'), ('i11', 'r2')]
pythonc4q11 = [('c9', 'a2'),('a2', 'f7')]
pythonc4q12 = [('c9', 'i19'), ('i19', 'a2'), ('c9', 'i5'), ('i5', 'f9'), ('f9', 'j2')]
pythonc4q13 = [('l7', 'i1')]
pythonc4q14 = [('c9', 'i7'), ('i7', 'c10')]
pythonc4q15 = [('c9', 'l1'), ('c9', 'i11')]
pythonc4q16 = [('c9', 'f8'), ('c9', 'i20'), ('i20', 'f6'), ('f6', 'r1'), ('f6', 'i7'), ('i7', 'c11')]
pythonc4q17 = [('c9', 'i6'), ('i6', 'c12'), ('c12', 'f9')]
pythonc4q18 = [('c9', 'i11')]
pythonc4q19 = [('l7', 't13'), ('t13', 'i1'), ('i1', 'i3')]
pythonc4q22 = [('c9', 'i7'), ('c9', 'w1'), ('w1', 'c4'), ('w1', 'f6'), ('f6', 'r1'), ('f6', 'i7'), ('i7', 'c4'), ('i7', 'a2'), ('i7', 'b2'),('f6', 'e3'),('e3', 'l5'),('c9', 'f7')]
pythonc4q23 = [('c9', 's26'), ('c9', 'j2')]
pythonc4q24 = [('c9', 'f8'), ('c9', 'c8'), ('c8', 'w1'), ('w1', 'c4'), ('w1', 'i7')]
pythonc4q26 = [('i1', 'c5'), ('c5', 'c9'), ('c9', 'i6'), ('i6', 'c4'), ('i6', 'l5'), ('i6', 'j2'), ('i6', 'e3'), ('e3', 'f6'), ('f6', 'r1'), ('f6', 's12'), ('f6', 'r2'), ('i1', 'l9')]
pythonc4q27 = [('c9', 'i21'), ('i21', 'w1'), ('w1', 'a2'), ('w1', 'c4'), ('w1', 'w1'), ('w1', 'a2'), ('w1', 'c4'), ('w1', 'o3'), ('o3', 'o3'), ('o3', 'o3'), ('o3', 't14')]
pythonc4q28 = [('c9', 'f1'),('c9', 'i22'), ('i22', 's13'), ('s13', 'w1'), ('w1', 'a2'), ('w1', 'c4'), ('w1', 'q1'), ('q1', 'l10')]
pythonc4q29 = [('c9', 's14'), ('s14', 's15'), ('s15', 'f6'), ('f6', 's9'), ('f6', 'i7'), ('i7', 'm1'), ('i7', 'c11')]
pythonc4q31 = [('c9', 'f8'), ('c9', 'f6'), ('f6', 'i7'), ('i7', 'c4'), ('c9', 'c9'), ('c9', 'f6'), ('f6', 'i7'), ('i7', 'c4'), ('c9', 'c9'), ('c9', 'f6'), ('f6', 'c4'), ('f6', 'i7'), ('c9', 'i5'), ('i5', 'c5'), ('c5', 'f6'), ('f6', 'i7'), ('i7', 'j2'), ('i7', 'l5')]

# %%
pythonc5q1 = [('i5','l2'),('l2','t9')]
pythonc5q2= [('i5','t9'),('t9','i1'),('i1','l5')]
pythonc5q3= [('i5','l13')]
pythonc5q4= [('i5','l2'),('l2','t9'),('t9','l14')]
pythonc5q5= [('i5','t11'),('t11','i12'),('i12','t18')]
pythonc5q6= [('i5','t19')]
pythonc5q7= [('i5','j3')]
pythonc5q8= [('i5','t4'),('t4','l15'),('l15','t3')]
pythonc5q9= [('i5','t20')]
pythonc5q10= [('i5','m7'),('m7','m8')]
pythonc5q11= [('i5','i1'),('i1','t21')]
pythonc5q12= [('i5','l2'),('l2','t9'),('t9','t10'),('t10','i29'),('i29','f6'),('f6','l6'),('f6','v6'),('v6','p1')]
pythonc5q13= [('c9','l2'),('l2','f6'),('f6','r1')]
pythonc5q14= [('c5','i12'),('i12','l5'),('l5','u3'),('l5','f6'),('f6','l6'),('f6','p1')]
pythonc5q15= [('l2','i7'),('i7','i5'),('i5','f6'),('f6','l6'),('f6','t12'),('t12','j4')]
pythonc5q16= [('i5','t11')]
pythonc5q17= [('i1','l2'),('l2','l23'),('l23','f6'),('f6','l6'),('f6','s11'),('s11','j2')]
pythonc5q18= [('l2','i5'),('i5','f6'),('f6','l6'),('f6','t9'),('l2','t11'),('t11','c5'),('c5','s12'),('c5','f6'),('f6','r1'),('f6','l5'),('l5','t24')]
pythonc5q19= [('c9','i1'),('i1','i3'),('i1','l2'),('l2','f6'),('f6','r1'),('c9','t11')]
pythonc5q20= [('e6','f6'),('f6','r1'),('f6','t22')]
pythonc5q21= [('l2','i5'),('l2','f6'),('l2','t9'),('l2','l2'),('l2','e7'),('l2','f6'),('l2','j2')]
pythonc5q22= [('l2','i5'),('l2','f6'),('f6','l6'),('l2','l16')]
pythonc5q23= [('l2','f6'),('l2','f6')]
pythonc5q24= [('l2','d5'),('d5','f6'),('f6','r1'),('f6','l17'),('l17','l18'),('l18','l15'),('l15','l14'),('l14','l19')]

# %%
pythonc6q1= [('c20','c3'),('c20','i1'),('c3','f6'),('f6','c16'),('u2','f6'),('r1','f6'),('f6','s20'),('u2','c14'),('c14','p1')]
pythonc6q2= [('c20','c3'),('c20','i1'),('c20','f6'),('c3','i7'),('f6','r1'),('f6','s20'),('f6','u2'),('f6','p1'),('u2','c14'),('i7','g1')]
pythonc6q3= [('c20','c3'),('c20','i1'),('c20','f6'),('c3','f6'),('f6','i7'),('f6','u2'),('f6','s20'),('f6','r1'),('i7','p1'),('u2','c14')]
pythonc6q4= [('c20','c3'),('c20','i1'),('c20','f6'),('c3','p1'),('c3','c32'),('c32','f6'),('f6','e3'),('f6','p3'),('f6','i7'),('f6','k1'),('f5','u2'),('f5','s20'),('f5','r1'),('u2','c14')]
pythonc6q5= [('i26','c33'),('i26','c20'),('c20','i3'),('c20','f6'),('f6','i35'),('f6','u2'),('f6','s20'),('f6','r1'),('i35','p1')]
pythonc6q6= [('c20','s29'),('c20','i4'),('c20','f6'),('c20','i1'),('c20','s20'),('c20','i3'),('s29','p1')]
pythonc6q7= [('c20','s29'),('c20','s20'),('c20','i1'),('c20','f6'),('c20','i4'),('s29','p1'),('p1','s25')]
pythonc6q8= [('c3','s29'),('c3','p1'),('c3','s20'),('c3','i1'),('c3','f6'),('a2','p1')]
pythonc6q9= [('c20','c3'),('c20','f6'),('c20','i3'),('f6','c3'),('f6','u2'),('f6','s20'),('f6','i1'),('f6','r1'),('c3','p1')]
pythonc6q10= [('c20','s29'),('c20','p1'),('c20','s29'),('c20','i1'),('c20','f6'),('c20','i4'),('p1','o3')]
pythonc6q11= [('c20','s29'),('c20','p1'),('c20','s20'),('c20','i1'),('c20','f6'),('c20','i4')]
pythonc6q12= [('c20','s29'),('c20','s20'),('c20','i1'),('c20','f6'),('s29','f13'),('f13','p1')]
pythonc6q13= [('c20',' c3'), ('c3',' u2'), ('u2',' p1'), ('p1',' s25'), ('c20',' i4'), ('c20','f6'), ('f6','i1'),('i1','s20'),('c20','f6'),('f6','r1'),('c20','i3'),('i3','i1')]
pythonc6q14= [('c20','s29'),('c20','o3'),('o3','p1'),('c20','s20'),('c20','i1'),('c20','f6')]
pythonc6q15= [('c20','f6'),('f6','r1'),('c20','c3'),('c3','p1'),('c20','i4'),('i4','i1')]
pythonc6q16= [('d8','c20'),('c20','i4'),('i4','i1'),('d8','p1'),('d8','c14'),('c14','p1'),('c14','k1'),('c14','v5'),('v5','o3'),('c14','f6'),('f6','r1'),('r1','v5'),('d8','p10')]
pythonc6q17= [('d8','c20'),('c20','i4'),('i4','i1'),('d8','p1'),('d8','c14'),('c14','p10'),('c14','f6'),('f6','r1'),('r1','v5'),('c14','v5'),('v5','o3'),('c14','k1')]
pythonc6q18= [('c20','i4'),('c20','c3'),('c3','f6'),('f6','r1'),('c3','o3'),('o3','p1')]
pythonc6q19= [('d8','c20'),('c20','i4'),('c20','p1'),('d8','c14'),('c14','p1'),('c14','f6'),('f6','r1'),('c14','v5'),('v5','o3'),('c14','k1')]
pythonc6q20= [('c3','p1'),('c3','w1'),('w1','c15'),('c15','s20'),('w1','e8'),('e8','b2'),('w1','p1'),('p1','s20'),('w1','t23')]
pythonc6q21= [('c3','c20'),('c3','w1'),('w1','i1'),('i1','t23'),('t23','s20'),('s20','e8'),('e8','b2'),('e8','i4'),('i4','p1'),('p1','t23'),('t23','d5'),('d5','p1'),('p1','e8'),('e8','p1')]
pythonc6q22= [('d8','c7'),('c7','c34'),('c34','f6'),('f6','i7'),('i7','c9'),('c9','p1'),('d8','f11'),('f11','s1'),('s1','i1'),('i1','f7')]

# %%
pythonc7q1 = [('c21','c22') , ('c22','i30') , ('i30','p1') , ('c21','i31')]
pythonc7q2 =  [('c21','c22') , ('c22','i30') , ('i30','s28') , ('c21','i31')] 
pythonc7q3 =  [('c21','f2') , ('f2','c24') , ('c24','p1') , ('p1','a4') , ('c21','c23') , ('c23','r12')]                            
pythonc7q4 =  [('c21','c25') , ('c25','c26') , ('c26','c27') , ('c21','c9') , ('c9','i30') , ('c9','p1')] 
pythonc7q5 =  [('c21','i31') , ('i31','p8') , ('c21','c22') , ('c22','i30') , ('c22','s28') , ('s28','c9') ,('c9','p1')] 
pythonc7q6 =  [('c21','i33') , ('i33','i14') , ('i14','i1') , ('i14','p1') , ('c21','c28') , ('c28','i30') , ('c28','r12') , ('r12', 'o3')]
pythonc7q7 =  [('c21','i33') , ('i33','p1') ,('p1','g2') , ('i33','p1') , ('p1','g3') , ('c21','c22') , ('c22','i30') , ('c22','i20') , ('c22','b4') , ('c22','c29') , ('c29','i30') , ('c29','r12') , ('r12','i21') , ('c22','c30') , ('c30','i30') , ('c30','r12') , ('r12','m9') , ('m9','i22')] 
pythonc7q8 =  [('c21','p1') , ('p1','r14') , ('c21','c22') , ('c22','i30') , ('c22','r12') , ('r12','j2') , ('j2','r14') , ('r14','s20')]
pythonc7q9 =  [('c21','i31') , ('i31','p1') , ('p1','o3') , ('i31','i14') , ('i14','i1') , ('c21','c22') , ('c22','i30') , ('c22','c29') , ('c29','a12') , ('c29','r12') , ('r12','o3') , ('o3','d9') , ('c29','c31') , ('c31','a12') , ('c31','r12') , ('r12','d9') , ('d9','o3')]
pythonc7q10 =  [('c21','i31') , ('i31','i34') , ('i34','i14') , ('i34','p1') , ('i14','i1') , ('i31','i34') , ('i34','i14') , ('i14','i1') , ('i34','p1') , ('c21','c9') , ('c9','i30') , ('c9','r12') , ('r12','o3') , ('c9','c9') , ('c9','i30') , ('c9','r12') , ('r12','o3')]

# %%
pythonnumpyq1 = [('a6', 's10'), ('a6', 'm4'), ('s10', 'p1'), ('p1', 'a2')]
pythonnumpyq2 = [('a6', 'l12'), ('l12', 'd3'), ('l12', 'p1')]
pythonnumpyq3 = [('a6', 's10'), ('a6', 'm4'), ('s10', 'p1'), ('s10', 's17')]
pythonnumpyq4 = [('a6', 's10'), ('a6', 'm4'), ('s10', 'n4'), ('s10', 'r3'), ('n4', 'p1')]
pythonnumpyq5 = [('e4', 'i23'), ('e4', 'l12'), ('e4', 'd3'), ('e4', 's17'), ('e4', 'n4'), ('s17', 'p1')]
pythonnumpyq6 = [('a7', 'p1'), ('a7', 'r3')]
pythonnumpyq7 = [('a6', 'p1'), ('a6', 'm4')]
pythonnumpyq8 = [('a6', 'm4'), ('a6', 's18'), ('s18', 'p1')]
pythonnumpyq9 = [('a6', 'm4'), ('a6', 'a2'), ('a2', 'p1'), ('p1', 'f6'), ('f6', 'n5'), ('f6', 'a2')]
pythonnumpyq10 = [('a6', 'l12'), ('a6', 'r4'), ('r4', 'p1'), ('p1', 'a2')]
pythonnumpyq11 = [('a6','l12'),('a6','r3'),('r3','p1'),('p1','a2')]
pythonnumpyq12 = [('l12','a6'),('l12','t16'),('a6','t15'),('a6','p1')]
pythonnumpyq13 = [('a7','p1'),('a7','r3')]
pythonnumpyq14 = [('z1','p1')]
pythonnumpyq15 = [('o4','p1')]
pythonnumpyq16 = [('f10','p1')]
pythonnumpyq17 = [('r5','r6'),('r6','r7'),('r5','p1'),('r7','s19')]
pythonnumpyq18 = [('i24','d4'),('i24','p1'),('d4','a7'),('a7','r3')]
pythonnumpyq19 = [('a6','s10'),('a6','m4'),('s10','p4'),('s10','a2'),('a2','p1')]
pythonnumpyq20 = [('a6','m4'),('m4','p1'),('m4','p4')]
pythonnumpyq21 = [('a6','l12'),('a6','s18'),('s18','p1')]
pythonnumpyq22 = [('s6','m5'),('s6','a2'),('a2','p1')]
pythonnumpyq23 = [('a6','m4'),('a6','a2'),('a2','p1')]
pythonnumpyq24 = [('a7','r3'),('r3','s20'),('s20','p1')]
pythonnumpyq25 = [('a6','m5'),('a6','s18'),('a6','a8'),('s18','p1')]
pythonnumpyq26 = [('a6','m5'),('a6','a9'),('m5','p1')]
pythonnumpyq27 = [('a6','m4'),('a6','d5'),('a6','i25'),('m4','p1'),('d5','a10')]
pythonnumpyq28 = [('a6','m4'),('a6','s22'),('a6','c13'),('a6','t17'),('a6','s4'),('a6','e5'),('a6','l11'),('s22','p1')]
pythonnumpyq29 = [('a6','m5'),('a6','c19'),('a6','a11'),('a6','p2'),('a6','r8'),('a6','r9'),('a6','s23'),('a6','r10'),('a11','p1')]
pythonnumpyq30 = [('a6','m4'),('a6','m6'),('a6','s24'),('a6','v3'),('a6','s25'),('a6','m9'),('m6','p1')]

# %%
pandasc1q1=[('d6','p5'), ('d6','s27')]
pandasc1q2=[('d6','p6'), ('d6','p7'), ('p7','r11'), ('p7','l12')]
pandasc1q3=[('d6','p7'), ('p7','c14'), ('c14','k1'), ('c14','v5')]
pandasc1q4=[('i26','p7'), ('i26','c14'), ('i26','c15'), ('p7','p1'), ('c14','k1'), ('c14','v5')]
pandasc1q5=[('r11','k2'), ('r11','i26'), ('i26','p7'), ('p7','n6'), ('p7','c16'), ('p7','p1'), ('p7','m2'), ('k2','p1'), ('k2','i7'), ('k2','e3'), ('k2','r12'), ('c16','r13'), ('c16','u1')]
pandasc1q6=[('i26','c14'), ('i26','p7'), ('p7','f6'), ('p7','i27'), ('c14','k1'), ('c14','v5'), ('f6','p1'), ('f6','i27')]
pandasc1q7=[('i26','p7'), ('p7','c14'), ('c14','k1'), ('c14','v5')]
pandasc1q8=[('t15','s18'), ('s18','p1')]
pandasc1q9=[('i26','p7'), ('p7','c15'), ('p7','s18'), ('p7','r1'), ('p7','r3')]

pandasc2q1=[('i26','c14'), ('c14','k1'), ('c14','v5'), ('c14','p7'), ('p7','f11')]
pandasc2q2=[('p7','a2'), ('p7','c14'), ('c14','k1'), ('c14','v5')]
pandasc2q3=[('p7','a2')]
pandasc2q4=[('i26','p7'), ('i26','c14'), ('i26','c15'), ('p7','p1'), ('p1','i28')]
pandasc2q5=[('i26','p7'), ('i26','c14'), ('c14','k1'), ('c14','v5'), ('p7','p1'), ('p7','o3')]
pandasc2q6=[('i26','p7'), ('i26','c14'), ('c14','k1'), ('c14','v5'), ('p7','f12')]
pandasc2q7=[('c17','p7'), ('p7','f12')]

pandasc3q1=[('i26','c14'), ('c14','k1'), ('c14','v5'), ('c14','p7'), ('p7','s26'), ('s26','p1')]
pandasc3q2=[('i26','c14'), ('c14','k1'), ('c14','v5'), ('c14','p7'), ('p7','s26'), ('s26','p1')]
pandasc3q3=[('i26','p7'), ('p7','c14'), ('c14','k1'), ('c14','v5'), ('c14','c18')]
pandasc3q4=[('i26','p7'), ('p7','c14'), ('c14','k1'), ('c14','v5'), ('c14','f12'), ('f12','c18')]
pandasc3q5=[('c20','b3'), ('b3','r5'), ('r5','o3'), ('b3','l12')]

pandasc4q1=[('i26','r15'), ('r15','s17')]
pandasc4q2=[('i26','r15'), ('r15','d7')]
pandasc4q3=[('i26','r15'), ('r15','h2')]
pandasc4q4=[('i26','r15'), ('r15','d8'), ('d8','g1'), ('g1','r12'), ('g1','p1')]
pandasc4q5=[('i26','r15'), ('r15','d8'), ('d8','g1'), ('g1','r12'), ('g1','p1')]
pandasc4q6=[('i26','r15'), ('r15','d8'), ('d8','g1'), ('g1','r12'), ('g1','a6')]

# %%
import networkx as nx

# %%
A = nx.DiGraph()

# %%
# %matplotlib inline

# %%
A.add_edges_from(pythonc1q2)
A.add_edges_from(pythonc1q3)
A.add_edges_from(pythonc1q4)
A.add_edges_from(pythonc1q5)
A.add_edges_from(pythonc1q6)
A.add_edges_from(pythonc1q7)
A.add_edges_from(pythonc1q8)
A.add_edges_from(pythonc1q9)
A.add_edges_from(pythonc1q10)
A.add_edges_from(pythonc2q1)
A.add_edges_from(pythonc2q2)
A.add_edges_from(pythonc2q3)
A.add_edges_from(pythonc2q4)
A.add_edges_from(pythonc2q5)
A.add_edges_from(pythonc2q6)
A.add_edges_from(pythonc2q7)
A.add_edges_from(pythonc2q8)
A.add_edges_from(pythonc2q9)
A.add_edges_from(pythonc2q10)
A.add_edges_from(pythonc2q11)
A.add_edges_from(pythonc2q12)
A.add_edges_from(pythonc2q13)
A.add_edges_from(pythonc2q14)
A.add_edges_from(pythonc2q15)
A.add_edges_from(pythonc2q16)
A.add_edges_from(pythonc2q17)
A.add_edges_from(pythonc2q18)
A.add_edges_from(pythonc2q19)
A.add_edges_from(pythonc2q20)
A.add_edges_from(pythonc3q1)
A.add_edges_from(pythonc3q2)
A.add_edges_from(pythonc3q3)
A.add_edges_from(pythonc3q4)
A.add_edges_from(pythonc3q5)
A.add_edges_from(pythonc3q6)
A.add_edges_from(pythonc3q7)
A.add_edges_from(pythonc3q8)
A.add_edges_from(pythonc3q9)
A.add_edges_from(pythonc3q10)
A.add_edges_from(pythonc3q11)
A.add_edges_from(pythonc3q12)
A.add_edges_from(pythonc3q13)
A.add_edges_from(pythonc3q14)
A.add_edges_from(pythonc3q15)
A.add_edges_from(pythonc3q16)
A.add_edges_from(pythonc3q17)
A.add_edges_from(pythonc3q18)
A.add_edges_from(pythonc3q19)
A.add_edges_from(pythonc3q20)
A.add_edges_from(pythonc4q1)
A.add_edges_from(pythonc4q2)
A.add_edges_from(pythonc4q3)
A.add_edges_from(pythonc4q4)
A.add_edges_from(pythonc4q5)
A.add_edges_from(pythonc4q7)
A.add_edges_from(pythonc4q8)
A.add_edges_from(pythonc4q9)
A.add_edges_from(pythonc4q11)
A.add_edges_from(pythonc4q12)
A.add_edges_from(pythonc4q13)
A.add_edges_from(pythonc4q14)
A.add_edges_from(pythonc4q15)
A.add_edges_from(pythonc4q16)
A.add_edges_from(pythonc4q17)
A.add_edges_from(pythonc4q18)
A.add_edges_from(pythonc4q19)
A.add_edges_from(pythonc4q22)
A.add_edges_from(pythonc4q23)
A.add_edges_from(pythonc4q24)
A.add_edges_from(pythonc4q26)
A.add_edges_from(pythonc4q27)
A.add_edges_from(pythonc4q28)
A.add_edges_from(pythonc4q29)
A.add_edges_from(pythonc4q31)
A.add_edges_from(pythonc5q1)
A.add_edges_from(pythonc5q2)
A.add_edges_from(pythonc5q3)
A.add_edges_from(pythonc5q4)
A.add_edges_from(pythonc5q5)
A.add_edges_from(pythonc5q6)
A.add_edges_from(pythonc5q7)
A.add_edges_from(pythonc5q8)
A.add_edges_from(pythonc5q9)
A.add_edges_from(pythonc5q10)
A.add_edges_from(pythonc5q11)
A.add_edges_from(pythonc5q12)
A.add_edges_from(pythonc5q13)
A.add_edges_from(pythonc5q14)
A.add_edges_from(pythonc5q15)
A.add_edges_from(pythonc5q16)
A.add_edges_from(pythonc5q17)
A.add_edges_from(pythonc5q18)
A.add_edges_from(pythonc5q19)
A.add_edges_from(pythonc5q20)
A.add_edges_from(pythonc5q21)
A.add_edges_from(pythonc5q22)
A.add_edges_from(pythonc5q23)
A.add_edges_from(pythonc5q24)
A.add_edges_from(pythonc6q1)
A.add_edges_from(pythonc6q2)
A.add_edges_from(pythonc6q3)
A.add_edges_from(pythonc6q4)
A.add_edges_from(pythonc6q5)
A.add_edges_from(pythonc6q6)
A.add_edges_from(pythonc6q7)
A.add_edges_from(pythonc6q8)
A.add_edges_from(pythonc6q9)
A.add_edges_from(pythonc6q10)
A.add_edges_from(pythonc6q11)
A.add_edges_from(pythonc6q12)
A.add_edges_from(pythonc6q13)
A.add_edges_from(pythonc6q14)
A.add_edges_from(pythonc6q15)
A.add_edges_from(pythonc6q16)
A.add_edges_from(pythonc6q17)
A.add_edges_from(pythonc6q18)
A.add_edges_from(pythonc6q19)
A.add_edges_from(pythonc6q20)
A.add_edges_from(pythonc6q21)
A.add_edges_from(pythonc6q22)
A.add_edges_from(pythonc7q1)
A.add_edges_from(pythonc7q2)
A.add_edges_from(pythonc7q3)
A.add_edges_from(pythonc7q4)
A.add_edges_from(pythonc7q5)
A.add_edges_from(pythonc7q6)
A.add_edges_from(pythonc7q7)
A.add_edges_from(pythonc7q8)
A.add_edges_from(pythonc7q9)
A.add_edges_from(pythonc7q10)
A.add_edges_from(pythonnumpyq1)
A.add_edges_from(pythonnumpyq2)
A.add_edges_from(pythonnumpyq3)
A.add_edges_from(pythonnumpyq4)
A.add_edges_from(pythonnumpyq5)
A.add_edges_from(pythonnumpyq6)
A.add_edges_from(pythonnumpyq7)
A.add_edges_from(pythonnumpyq8)
A.add_edges_from(pythonnumpyq9)
A.add_edges_from(pythonnumpyq10)
A.add_edges_from(pythonnumpyq11)
A.add_edges_from(pythonnumpyq12)
A.add_edges_from(pythonnumpyq13)
A.add_edges_from(pythonnumpyq14)
A.add_edges_from(pythonnumpyq15)
A.add_edges_from(pythonnumpyq16)
A.add_edges_from(pythonnumpyq17)
A.add_edges_from(pythonnumpyq18)
A.add_edges_from(pythonnumpyq19)
A.add_edges_from(pythonnumpyq20)
A.add_edges_from(pythonnumpyq21)
A.add_edges_from(pythonnumpyq22)
A.add_edges_from(pythonnumpyq23)
A.add_edges_from(pythonnumpyq24)
A.add_edges_from(pythonnumpyq25)
A.add_edges_from(pythonnumpyq26)
A.add_edges_from(pythonnumpyq27)
A.add_edges_from(pythonnumpyq28)
A.add_edges_from(pythonnumpyq29)
A.add_edges_from(pythonnumpyq30)
A.add_edges_from(pandasc1q1)
A.add_edges_from(pandasc1q2)
A.add_edges_from(pandasc1q3)
A.add_edges_from(pandasc1q4)
A.add_edges_from(pandasc1q5)
A.add_edges_from(pandasc1q6)
A.add_edges_from(pandasc1q7)
A.add_edges_from(pandasc1q8)
A.add_edges_from(pandasc1q9)
A.add_edges_from(pandasc2q1)
A.add_edges_from(pandasc2q2)
A.add_edges_from(pandasc2q3)
A.add_edges_from(pandasc2q4)
A.add_edges_from(pandasc2q5)
A.add_edges_from(pandasc2q6)
A.add_edges_from(pandasc2q7)
A.add_edges_from(pandasc3q1)
A.add_edges_from(pandasc3q2)
A.add_edges_from(pandasc3q3)
A.add_edges_from(pandasc3q4)
A.add_edges_from(pandasc3q5)
A.add_edges_from(pandasc4q1)
A.add_edges_from(pandasc4q2)
A.add_edges_from(pandasc4q3)
A.add_edges_from(pandasc4q4)
A.add_edges_from(pandasc4q5)
A.add_edges_from(pandasc4q6)

# %%
A

# %%
nx.draw(A,with_labels=True)

# %%
#Total number of topic connections
A.number_of_edges()
# Out:
# 532

# %%
#total number of topics
A.number_of_nodes()
# Out:
# 255

# %%
#printing all the edges
[e for e in A.edges]
# Out:
# [('i24', 'd4'),
#  ('i24', 'p1'),
#  ('i26', 'c20'),
#  ('i26', 'r15'),
#  ('i26', 'p7'),
#  ('i26', 'c33'),
#  ('i26', 'c15'),
#  ('i26', 'c14'),
#  ('d8', 'c20'),
#  ('d8', 'p1'),
#  ('d8', 'g1'),
#  ('d8', 'p10'),
#  ('d8', 'f11'),
#  ('d8', 'c7'),
#  ('d8', 'c14'),
#  ('d9', 'o3'),
#  ('d6', 'p7'),
#  ('d6', 'p6'),
#  ('d6', 's27'),
#  ('d6', 'p5'),
#  ('d4', 'a7'),
#  ('d5', 'p1'),
#  ('d5', 'a10'),
#  ('d5', 'f6'),
#  ('q1', 'l10'),
#  ('c12', 'f9'),
#  ('c17', 'p7'),
#  ('c16', 'u1'),
#  ('c16', 'r13'),
#  ('c15', 's20'),
#  ('c14', 'p1'),
#  ('c14', 'p7'),
#  ('c14', 'f6'),
#  ('c14', 'p10'),
#  ('c14', 'k1'),
#  ('c14', 'c18'),
#  ('c14', 'v5'),
#  ('c14', 'f12'),
#  ('r14', 's20'),
#  ('r15', 'h2'),
#  ('r15', 'd7'),
#  ('r15', 's17'),
#  ('r15', 'd8'),
#  ('r12', 'i21'),
#  ('r12', 'd9'),
#  ('r12', 'o3'),
#  ('r12', 'j2'),
#  ('r12', 'm9'),
#  ('g1', 'p1'),
#  ('g1', 'r12'),
#  ('g1', 'a6'),
#  ('r11', 'k2'),
#  ('r11', 'i26'),
#  ('r4', 'p1'),
#  ('p7', 'p1'),
# ...

# %%
nx.draw(A, with_labels=True, font_weight='bold', node_size=500, node_color='green')

# %% [markdown]
# # KNOWLEDGE SCORE

# %%
nx.set_node_attributes(A,100,'score')

# %% [markdown]
# # Problem solving score

# %%
A['i4']['p1']['weight']=50
A['k2']['r12']['weight']=50
A['f12']['c18']['weight']=50
A['c17']['p7']['weight']=5
A['b3']['r5']['weight']=50
A['r15']['s17']['weight']=2
A['d6']['p6']['weight']=50
A['r3']['p1']['weight']=50
A['c21']['c9']['weight']=50
A['c9']['f6']['weight']=50
A['w1']['l2']['weight']=4
A['c3']['s29']['weight']=50

# %%
d=nx.get_edge_attributes(A,'weight')

# %%
d
# Out:
# {('b3', 'r5'): 50,
#  ('c17', 'p7'): 5,
#  ('c21', 'c9'): 50,
#  ('c3', 's29'): 50,
#  ('c9', 'f6'): 50,
#  ('d6', 'p6'): 50,
#  ('f12', 'c18'): 50,
#  ('i4', 'p1'): 50,
#  ('k2', 'r12'): 50,
#  ('r15', 's17'): 2,
#  ('r3', 'p1'): 50,
#  ('w1', 'l2'): 4}

# %%
{k: v for k, v in sorted(d.items(), key=lambda item: item[1])}
# Out:
# {('b3', 'r5'): 50,
#  ('c17', 'p7'): 5,
#  ('c21', 'c9'): 50,
#  ('c3', 's29'): 50,
#  ('c9', 'f6'): 50,
#  ('d6', 'p6'): 50,
#  ('f12', 'c18'): 50,
#  ('i4', 'p1'): 50,
#  ('k2', 'r12'): 50,
#  ('r15', 's17'): 2,
#  ('r3', 'p1'): 50,
#  ('w1', 'l2'): 4}

# %%
from heapq import nsmallest 
  
# Initial Dictionary 
my_dict = d
  
print("Initial Dictionary:") 
print(my_dict, "\n") 
  
Threesmallest=nsmallest(3, my_dict, key = my_dict.get) 
  
print("Dictionary with 3 lowest values:") 
print("Keys: Values") 
  
for val in Threesmallest: 
    print(val, ":", my_dict.get(val))
# Out:
# Initial Dictionary:
# ({('c17', 'p7'): 5, ('w1', 'l2'): 4, ('f12', 'c18'): 50, ('r15', 's17'): 2, ('r3', 'p1'): 50, ('c3', 's29'): 50, ('i4', 'p1'): 50, ('d6', 'p6'): 50, ('c21', 'c9'): 50, ('c9', 'f6'): 50, ('b3', 'r5'): 50, ('k2', 'r12'): 50}, '\n')
# Dictionary with 3 lowest values:
# Keys: Values
# (('r15', 's17'), ':', 2)
# (('w1', 'l2'), ':', 4)
# (('c17', 'p7'), ':', 5)

# %%
d
# Out:
# {('b3', 'r5'): 50,
#  ('c17', 'p7'): 5,
#  ('c21', 'c9'): 50,
#  ('c3', 's29'): 50,
#  ('c9', 'f6'): 50,
#  ('d6', 'p6'): 50,
#  ('f12', 'c18'): 50,
#  ('i4', 'p1'): 50,
#  ('k2', 'r12'): 50,
#  ('r15', 's17'): 2,
#  ('r3', 'p1'): 50,
#  ('w1', 'l2'): 4}

# %%
A

# %%
A.dict_to_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c281b9949ad> in <module>()
# ----> 1 A.dict_to_dict
#
# NameError: name 'A' is not defined

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7d157d7c000a> in <module>()
# ----> 1 A
#
# NameError: name 'A' is not defined

# %%
from networkx import to_dict_of_dicts

# %%
to_dict_of_dicts(A)
# Out:
# {' c3': {},
#  ' i4': {},
#  ' p1': {},
#  ' s25': {},
#  ' u2': {},
#  'a1': {},
#  'a10': {},
#  'a11': {'p1': {}},
#  'a12': {},
#  'a2': {'f7': {}, 'p1': {}, 'p2': {}, 's4': {}},
#  'a3': {},
#  'a4': {'f1': {}},
#  'a5': {'c8': {}, 'w1': {}},
#  'a6': {'a11': {},
#   'a2': {},
#   'a8': {},
#   'a9': {},
#   'c13': {},
#   'c19': {},
#   'd5': {},
#   'e5': {},
#   'i25': {},
#   'l11': {},
#   'l12': {},
#   'm4': {},
#   'm5': {},
#   'm6': {},
#   'm9': {},
#   'p1': {},
#   'p2': {},
#   'r10': {},
#   'r3': {},
#   'r4': {},
#   'r8': {},
#   'r9': {},
#   's10': {},
#   's18': {},
#   's22': {},
#   's23': {},
#   's24': {},
#   's25': {},
#   's4': {},
#   't15': {},
#   't17': {},
#   'v3': {}},
#  'a7': {'p1': {}, 'r3': {}},
#  'a8': {},
#  'a9': {},
#  'b1': {},
#  'b2': {},
#  'b3': {'l12': {}, 'r5': {}},
#  'b4': {},
#  'c1': {'a2': {}},
#  'c10': {},
#  'c11': {},
#  'c12': {'f9': {}},
#  'c13': {},
#  'c14': {'c18': {},
#   'f12': {},
#   'f6': {},
#   'k1': {},
# ...

# %%
A('i4','p1')['weight']=50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-aff6f0e64f07> in <module>()
# ----> 1 A('i4','p1')['weight']=50
#
# TypeError: 'DiGraph' object is not callable
